# %%
import cv2
import matplotlib.pyplot as plt
from PIL import Image

# %%
from ultralytics import YOLO

# %%
model = YOLO("./runs/detect/train3/weights/best.pt")

# %%
image = cv2.imread("../data/tests/stop-634941_1280.jpg")
results = model([image], imgsz=320)
results = results[0]
# Out:
# 0: 224x320 1 stop, 34.7ms
# Speed: 0.0ms preprocess, 34.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 320)

# %%
for r in results:
    im_array = r.plot()
    im = Image.fromarray(im_array[..., ::-1])
    plt.imshow(im)
