# %%
import torch
import os
import cv2
import itertools
import numpy as np
import matplotlib.pyplot as plt

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='./yolov5/runs/train/exp3/weights/best.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\ADMIN/.cache\torch\hub\master.zip
# YOLOv5  2023-12-10 Python-3.9.13 torch-2.1.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %%
image = cv2.imread("../data/tests/stop-634941_1280.jpg")[:, :, ::-1]
result = model(image, size=320)
result.print() 
result.show()
# Out:
# image 1/1: 854x1280 1 stop
# Speed: 4.0ms pre-process, 42.1ms inference, 1.0ms NMS per image at shape (1, 3, 224, 320)
# <PIL.Image.Image image mode=RGB size=1280x854>

# %%
result.xyxy[0]
# Out:
# tensor([[7.60717e+02, 1.07492e+02, 1.09311e+03, 5.45671e+02, 8.72095e-01, 3.00000e+00]])

# %% [markdown]
#             x1             y1          x2           y2          proba           class
# tensor([[7.60717e+02, 1.07492e+02, 1.09311e+03, 5.45671e+02, 8.72095e-01, 3.00000e+00]])
